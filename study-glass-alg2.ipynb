# %% [markdown]
# # Study – Glass – Stretcher: round robing

# %%
import pandas as pd
import tensorflow as tf

from milp import codify_network
from teste import get_minimal_explanation
# Out:
# 2023-06-20 16:29:22.447748: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-20 16:29:22.705493: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-06-20 16:29:22.705529: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-06-20 16:29:22.738258: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-06-20 16:29:23.849800: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-06-20 16:29:23.849891: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-06-20 16:29:23.849899: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# For type annotations
import numpy as np

# %%
dataset_name = 'glass'

training_data = pd.read_csv(f'datasets/{dataset_name}/train.csv')
testing_data = pd.read_csv(f'datasets/{dataset_name}/test.csv')

dataframe = pd.concat([training_data, testing_data])

keras_model = tf.keras.models.load_model(f'datasets/{dataset_name}/model_2layers_{dataset_name}.h5')

data = dataframe.to_numpy()
n_classes = dataframe['target'].nunique()
# Out:
# 2023-06-20 16:29:25.169000: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-06-20 16:29:25.169049: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-06-20 16:29:25.169074: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (tiago-lab-pc): /proc/driver/nvidia/version does not exist
# 2023-06-20 16:29:25.169348: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
mp_model, output_bounds = codify_network(keras_model, dataframe, 'fischetti', relax_constraints=False)

# %% [markdown]
# ### Printing What the Model Predicted
#
# _Aka_ printing the network output.

# %%
# i = 134 is also a nice value to study
i = 138
print('i =', i)
network_input = data[i, :-1]
network_input = tf.reshape(tf.constant(network_input), [1, -1])
network_output = keras_model.predict(tf.constant(network_input))[0]
network_output = tf.argmax(network_output)

predictions = keras_model.predict(tf.constant(network_input))[0, 0]

print(f'Predictions: (ndarray[ndarray[{type(predictions)}]])', predictions)
classification: np.int64 = network_output.numpy()
print(f'Network output: ({type(classification)})', classification)
# Out:
# i = 138
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predictions: (ndarray[ndarray[<class 'numpy.float32'>]]) 0.0007575714
# Network output: (<class 'numpy.int64'>) 1

# %% [markdown]
# ### Printing the Minimal Explanation
#
# Minimal eplanations only indicates which inputs are relevant to get to a conclusion.
#
# **Note:** The explanation happens _after_ the keras_model make its predictions.

# %%
mdl_aux = mp_model.clone()

minimal_explanation = get_minimal_explanation(mdl_aux, network_input, network_output, n_classes, 'fischetti', output_bounds)
minimal_explanation
# Out:
# [docplex.mp.LinearConstraint[input1](x_0,EQ,2.967691214515491),
#  docplex.mp.LinearConstraint[input4](x_3,EQ,-1.408120229258977),
#  docplex.mp.LinearConstraint[input6](x_5,EQ,-0.790702170757714),
#  docplex.mp.LinearConstraint[input7](x_6,EQ,4.24127975754059),
#  docplex.mp.LinearConstraint[input8](x_7,EQ,-0.3615292659832898),
#  docplex.mp.LinearConstraint[input9](x_8,EQ,-0.6037614142464092)]

# %% [markdown]
# > The keras_model predicted $C_1$ because:
# >
# > $x_0 = 2.967691214515491$,
# >
# > $x_3 = -1.408120229258977$,
# >
# > $x_5 = -0.790702170757714$,
# >
# > $x_6 = 4.24127975754059$,
# >
# > $x_7 = -0.3615292659832898$ and
# >
# > $x_8 = -0.6037614142464092$.

# %% [markdown]
# ### Trying to Improve the Explanation
#
# Given a minimal explanation, can we improve it?

# %% [markdown]
# Constraints of type $x = c$ are equivalent to $x \le c \land x \ge c$.
#
# Therefore, we need to substitute each $x = c$ constraint by the $x \le c$ and $x \ge c$ constraints.
#
# Then, we try stretching the interval by substituting $x \le c$ by $x \le c + \Delta x$ and see if our prediction changes. If the prediction stays the same, then we substitue and try stretching it again. If the prediction changes, then this new interval isn't valid and we don't substitute. We found the upper bound of the interval, i.e. $x \le c$.
#
# Then we try to stretch the interval to fin the lower bound. Analogously, We try substituting $c \ge x$ by ????/
#
#
# We will end up with a pair of constraints the looks like $c - k_l \cdot \Delta{x} \le x$ and $x \le c + k_u \cdot \Delta{x}$, i.e. this pair represents $c - k_l \cdot \Delta{x} \le x \le c + k_u \cdot \Delta{x}$.

# %% [markdown]
# ### Setting Up

# %%
import docplex

# %%
minimal_model = mdl_aux
testing_model = minimal_model.clone()

# %% [markdown]
# #### Quick Sratch

# %%
linear_constraints = testing_model.find_matching_linear_constraints('input')
linear_constraints
# Out:
# [docplex.mp.LinearConstraint[input1](x_0,EQ,2.967691214515491),
#  docplex.mp.LinearConstraint[input4](x_3,EQ,-1.408120229258977),
#  docplex.mp.LinearConstraint[input6](x_5,EQ,-0.790702170757714),
#  docplex.mp.LinearConstraint[input7](x_6,EQ,4.24127975754059),
#  docplex.mp.LinearConstraint[input8](x_7,EQ,-0.3615292659832898),
#  docplex.mp.LinearConstraint[input9](x_8,EQ,-0.6037614142464092)]

# %%
linear_constraints = testing_model.find_matching_linear_constraints('input')

for constraint in linear_constraints:
	testing_model.remove_constraint(constraint)
	testing_model.add_constraint(constraint.lhs <= constraint.rhs.clone(), 'input LE')
	testing_model.add_constraint(constraint.lhs >= constraint.rhs.clone(), 'input GE')

# %%
linear_constraints = testing_model.find_matching_linear_constraints('input')
linear_constraints
# Out:
# [docplex.mp.LinearConstraint[input LE](x_0,LE,2.967691214515491),
#  docplex.mp.LinearConstraint[input GE](x_0,GE,2.967691214515491),
#  docplex.mp.LinearConstraint[input LE](x_3,LE,-1.408120229258977),
#  docplex.mp.LinearConstraint[input GE](x_3,GE,-1.408120229258977),
#  docplex.mp.LinearConstraint[input LE](x_5,LE,-0.790702170757714),
#  docplex.mp.LinearConstraint[input GE](x_5,GE,-0.790702170757714),
#  docplex.mp.LinearConstraint[input LE](x_6,LE,4.24127975754059),
#  docplex.mp.LinearConstraint[input GE](x_6,GE,4.24127975754059),
#  docplex.mp.LinearConstraint[input LE](x_7,LE,-0.3615292659832898),
#  docplex.mp.LinearConstraint[input GE](x_7,GE,-0.3615292659832898),
#  docplex.mp.LinearConstraint[input LE](x_8,LE,-0.6037614142464092),
#  docplex.mp.LinearConstraint[input GE](x_8,GE,-0.6037614142464092)]

# %%
id(linear_constraints[0]) == id(linear_constraints[0])
# Out:
# True

# %%
def get_x_ge_value_constraints(linear_constraints):
    # x >= c
    ge_constraints = []
    for xp in linear_constraints:
        if xp.sense == docplex.mp.constants.ComparisonType.GE:
            ge_constraints.append(xp)
    return ge_constraints

# %%
def get_x_le_value_constraints(linear_constraints):
    # x <= c
    le_constraints = []
    for xp in linear_constraints:
        if xp.sense == docplex.mp.constants.ComparisonType.LE:
            le_constraints.append(xp)
    return le_constraints

# %%
epsilon = 0.01

variables = testing_model.find_matching_vars('x')

print('Initial constraints:')
print(get_x_ge_value_constraints(linear_constraints))
print(get_x_le_value_constraints(linear_constraints))

testing_model.solve()

# Expand upper end
remaining_constraints_to_expand = get_x_le_value_constraints(linear_constraints)

# while remaining_constraints_to_expand != []:
while True:
	if remaining_constraints_to_expand == []:
		break
	
	constraint_ids_to_remove = []

	for constraint in remaining_constraints_to_expand:
		print(constraint)
		constraint.rhs += epsilon
		testing_model.solve()
		if testing_model.solution is not None or constraint.rhs.constant >= constraint.lhs.ub:
			constraint.rhs -= epsilon  # Undoes the last operation
			constraint_ids_to_remove.append(id(constraint))

	remaining_constraints_to_expand = [c for c in remaining_constraints_to_expand if id(c) not in constraint_ids_to_remove]


# Expand lower end
remaining_constraints_to_expand = get_x_ge_value_constraints(linear_constraints)

# while remaining_constraints_to_expand != []:
while True:
	if remaining_constraints_to_expand == []:
		break

	constraint_ids_to_remove = []

	for constraint in remaining_constraints_to_expand:
		print(constraint)
		constraint.rhs -= epsilon
		testing_model.solve()
		if testing_model.solution is not None or constraint.rhs.constant <= constraint.lhs.lb:
			constraint.rhs += epsilon  # Undoes the last operation
			constraint_ids_to_remove.append(id(constraint))

	remaining_constraints_to_expand = [c for c in remaining_constraints_to_expand if id(c) not in constraint_ids_to_remove]


print()
print('Final constraints:')
print(get_x_ge_value_constraints(linear_constraints))
print(get_x_le_value_constraints(linear_constraints))
# Out:
# Initial constraints:
# [docplex.mp.LinearConstraint[input GE](x_0,GE,2.967691214515491), docplex.mp.LinearConstraint[input GE](x_3,GE,-1.408120229258977), docplex.mp.LinearConstraint[input GE](x_5,GE,-0.790702170757714), docplex.mp.LinearConstraint[input GE](x_6,GE,4.24127975754059), docplex.mp.LinearConstraint[input GE](x_7,GE,-0.3615292659832898), docplex.mp.LinearConstraint[input GE](x_8,GE,-0.6037614142464092)]
# [docplex.mp.LinearConstraint[input LE](x_0,LE,2.967691214515491), docplex.mp.LinearConstraint[input LE](x_3,LE,-1.408120229258977), docplex.mp.LinearConstraint[input LE](x_5,LE,-0.790702170757714), docplex.mp.LinearConstraint[input LE](x_6,LE,4.24127975754059), docplex.mp.LinearConstraint[input LE](x_7,LE,-0.3615292659832898), docplex.mp.LinearConstraint[input LE](x_8,LE,-0.6037614142464092)]
# input LE: x_0 <= 2.967691214515491
# input LE: x_3 <= -1.408120229258977
# input LE: x_5 <= -0.790702170757714
# input LE: x_6 <= 4.24127975754059
# input LE: x_7 <= -0.3615292659832898
# input LE: x_8 <= -0.6037614142464092
# input LE: x_0 <= 2.977691214515491
# input LE: x_3 <= -1.398120229258977
# input LE: x_5 <= -0.780702170757714
# input LE: x_6 <= 4.25127975754059
# input LE: x_7 <= -0.3515292659832898
# input LE: x_8 <= -0.5937614142464092
# input LE: x_0 <= 2.9876912145154906
# input LE: x_3 <= -1.388120229258977
# input LE: x_5 <= -0.770702170757714
# input LE: x_6 <= 4.261279757540589
# input LE: x_7 <= -0.3415292659832898
# input LE: x_8 <= -0.5837614142464091
# input LE: x_0 <= 2.9976912145154904
# input LE: x_3 <= -1.378120229258977
# input LE: x_5 <= -0.760702170757714
# input LE: x_6 <= 4.271279757540589
# input LE: x_7 <= -0.3315292659832898
# input LE: x_8 <= -0.5737614142464091
# input LE: x_0 <= 3.00769121451549
# input LE: x_3 <= -1.368120229258977
# input LE: x_5 <= -0.750702170757714
# input LE: x_6 <= 4.281279757540589
# input LE: x_7 <= -0.3215292659832898
# input LE: x_8 <= -0.5637614142464091
# input LE: x_0 <= 3.01769121451549
# input LE: x_3 <= -1.358120229258977
# input LE: x_5 <= -0.7407021707577139
# input LE: x_6 <= 4.291279757540589
# input LE: x_7 <= -0.3115292659832898
# input LE: x_8 <= -0.5537614142464091
# input LE: x_0 <= 3.0276912145154897
# input LE: x_3 <= -1.348120229258977
# input LE: x_5 <= -0.7307021707577139
# input LE: x_6 <= 4.3012797575405886
# input LE: x_7 <= -0.3015292659832898
# input LE: x_8 <= -0.5437614142464091
# input LE: x_0 <= 3.0376912145154895
# input LE: x_3 <= -1.338120229258977
# input LE: x_5 <= -0.7207021707577139
# input LE: x_6 <= 4.311279757540588
# input LE: x_7 <= -0.29152926598328976
# input LE: x_8 <= -0.5337614142464091
# input LE: x_0 <= 3.0476912145154893
# input LE: x_3 <= -1.3281202292589769
# input LE: x_5 <= -0.7107021707577139
# input LE: x_6 <= 4.321279757540588
# input LE: x_7 <= -0.28152926598328976
# input LE: x_8 <= -0.5237614142464091
# input LE: x_0 <= 3.057691214515489
# input LE: x_3 <= -1.3181202292589769
# input LE: x_5 <= -0.7007021707577139
# input LE: x_6 <= 4.331279757540588
# input LE: x_7 <= -0.27152926598328975
# input LE: x_8 <= -0.5137614142464091
# input LE: x_0 <= 3.067691214515489
# input LE: x_3 <= -1.3081202292589769
# input LE: x_5 <= -0.6907021707577139
# input LE: x_6 <= 4.341279757540588
# input LE: x_7 <= -0.26152926598328974
# input LE: x_8 <= -0.5037614142464091
# input LE: x_0 <= 3.0776912145154887
# input LE: x_3 <= -1.2981202292589769
# input LE: x_5 <= -0.6807021707577139
# input LE: x_6 <= 4.3512797575405875
# input LE: x_7 <= -0.25152926598328973
# input LE: x_8 <= -0.49376141424640907
# input LE: x_0 <= 3.0876912145154884
# input LE: x_3 <= -1.2881202292589768
# input LE: x_5 <= -0.6707021707577139
# input LE: x_6 <= 4.361279757540587
# input LE: x_7 <= -0.24152926598328972
# input LE: x_8 <= -0.48376141424640906
# input LE: x_0 <= 3.0976912145154882
# input LE: x_3 <= -1.2781202292589768
# input LE: x_5 <= -0.6607021707577139
# input LE: x_6 <= 4.371279757540587
# input LE: x_7 <= -0.2315292659832897
# input LE: x_8 <= -0.47376141424640905
# input LE: x_0 <= 3.107691214515488
# input LE: x_3 <= -1.2681202292589768
# input LE: x_5 <= -0.6507021707577139
# input LE: x_6 <= 4.381279757540587
# input LE: x_7 <= -0.2215292659832897
# input LE: x_8 <= -0.46376141424640904
# input LE: x_0 <= 3.117691214515488
# input LE: x_3 <= -1.2581202292589768
# input LE: x_5 <= -0.6407021707577139
# input LE: x_6 <= 4.391279757540587
# input LE: x_7 <= -0.2115292659832897
# input LE: x_8 <= -0.45376141424640903
# input LE: x_0 <= 3.1276912145154876
# input LE: x_3 <= -1.2481202292589768
# input LE: x_5 <= -0.6307021707577138
# input LE: x_6 <= 4.401279757540586
# input LE: x_7 <= -0.20152926598328968
# input LE: x_8 <= -0.443761414246409
# input LE: x_0 <= 3.1376912145154874
# input LE: x_3 <= -1.2381202292589768
# input LE: x_5 <= -0.6207021707577138
# input LE: x_6 <= 4.411279757540586
# input LE: x_7 <= -0.19152926598328968
# input LE: x_8 <= -0.433761414246409
# input LE: x_0 <= 3.147691214515487
# input LE: x_3 <= -1.2281202292589768
# input LE: x_5 <= -0.6107021707577138
# input LE: x_6 <= 4.421279757540586
# input LE: x_7 <= -0.18152926598328967
# input LE: x_8 <= -0.423761414246409
# input LE: x_0 <= 3.157691214515487
# input LE: x_3 <= -1.2181202292589768
# input LE: x_5 <= -0.6007021707577138
# input LE: x_6 <= 4.431279757540586
# input LE: x_7 <= -0.17152926598328966
# input LE: x_8 <= -0.413761414246409
# input LE: x_0 <= 3.1676912145154867
# input LE: x_3 <= -1.2081202292589768
# input LE: x_5 <= -0.5907021707577138
# input LE: x_6 <= 4.441279757540586
# input LE: x_7 <= -0.16152926598328965
# input LE: x_8 <= -0.403761414246409
# input LE: x_0 <= 3.1776912145154865
# input LE: x_3 <= -1.1981202292589768
# input LE: x_5 <= -0.5807021707577138
# input LE: x_6 <= 4.451279757540585
# input LE: x_7 <= -0.15152926598328964
# input LE: x_8 <= -0.393761414246409
# input LE: x_0 <= 3.1876912145154863
# input LE: x_3 <= -1.1881202292589768
# input LE: x_5 <= -0.5707021707577138
# input LE: x_6 <= 4.461279757540585
# input LE: x_7 <= -0.14152926598328963
# input LE: x_8 <= -0.38376141424640897
# input LE: x_0 <= 3.197691214515486
# input LE: x_3 <= -1.1781202292589767
# input LE: x_5 <= -0.5607021707577138
# input LE: x_6 <= 4.471279757540585
# input LE: x_7 <= -0.13152926598328962
# input LE: x_8 <= -0.37376141424640896
# input LE: x_0 <= 3.207691214515486
# input LE: x_3 <= -1.1681202292589767
# input LE: x_5 <= -0.5507021707577138
# input LE: x_6 <= 4.481279757540585
# input LE: x_7 <= -0.12152926598328963
# input LE: x_8 <= -0.36376141424640895
# input LE: x_0 <= 3.2176912145154857
# input LE: x_3 <= -1.1581202292589767
# input LE: x_5 <= -0.5407021707577138
# input LE: x_6 <= 4.4912797575405845
# input LE: x_7 <= -0.11152926598328963
# input LE: x_8 <= -0.35376141424640895
# input LE: x_0 <= 3.2276912145154855
# input LE: x_3 <= -1.1481202292589767
# input LE: x_5 <= -0.5307021707577138
# input LE: x_6 <= 4.501279757540584
# input LE: x_7 <= -0.10152926598328964
# input LE: x_8 <= -0.34376141424640894
# input LE: x_0 <= 3.2376912145154852
# input LE: x_3 <= -1.1381202292589767
# input LE: x_5 <= -0.5207021707577137
# input LE: x_6 <= 4.511279757540584
# input LE: x_7 <= -0.09152926598328964
# input LE: x_8 <= -0.3337614142464089
# input LE: x_0 <= 3.247691214515485
# input LE: x_3 <= -1.1281202292589767
# input LE: x_5 <= -0.5107021707577137
# input LE: x_6 <= 4.521279757540584
# input LE: x_7 <= -0.08152926598328965
# input LE: x_8 <= -0.3237614142464089
# input LE: x_0 <= 3.257691214515485
# input LE: x_3 <= -1.1181202292589767
# input LE: x_5 <= -0.5007021707577137
# input LE: x_6 <= 4.531279757540584
# input LE: x_7 <= -0.07152926598328965
# input LE: x_8 <= -0.3137614142464089
# input LE: x_0 <= 3.2676912145154846
# input LE: x_3 <= -1.1081202292589767
# input LE: x_5 <= -0.4907021707577137
# input LE: x_6 <= 4.541279757540583
# input LE: x_7 <= -0.06152926598328965
# input LE: x_8 <= -0.3037614142464089
# input LE: x_0 <= 3.2776912145154844
# input LE: x_3 <= -1.0981202292589767
# input LE: x_5 <= -0.4807021707577137
# input LE: x_6 <= 4.551279757540583
# input LE: x_7 <= -0.05152926598328965
# input LE: x_8 <= -0.2937614142464089
# input LE: x_0 <= 3.287691214515484
# input LE: x_3 <= -1.0881202292589767
# input LE: x_5 <= -0.4707021707577137
# input LE: x_6 <= 4.561279757540583
# input LE: x_7 <= -0.04152926598328965
# input LE: x_8 <= -0.2837614142464089
# input LE: x_0 <= 3.297691214515484
# input LE: x_3 <= -1.0781202292589767
# input LE: x_5 <= -0.4607021707577137
# input LE: x_6 <= 4.571279757540583
# input LE: x_7 <= -0.031529265983289645
# input LE: x_0 <= 3.3076912145154838
# input LE: x_5 <= -0.4507021707577137
# input LE: x_0 <= 3.3176912145154835
# input LE: x_0 <= 3.3276912145154833
# input LE: x_0 <= 3.337691214515483
# input LE: x_0 <= 3.347691214515483
# input LE: x_0 <= 3.3576912145154827
# input LE: x_0 <= 3.3676912145154825
# input LE: x_0 <= 3.3776912145154823
# input LE: x_0 <= 3.387691214515482
# input LE: x_0 <= 3.397691214515482
# input LE: x_0 <= 3.4076912145154816
# input LE: x_0 <= 3.4176912145154814
# input LE: x_0 <= 3.427691214515481
# input LE: x_0 <= 3.437691214515481
# input LE: x_0 <= 3.4476912145154808
# input LE: x_0 <= 3.4576912145154806
# input LE: x_0 <= 3.4676912145154803
# input LE: x_0 <= 3.47769121451548
# input LE: x_0 <= 3.48769121451548
# input LE: x_0 <= 3.4976912145154797
# input LE: x_0 <= 3.5076912145154795
# input LE: x_0 <= 3.5176912145154793
# input LE: x_0 <= 3.527691214515479
# input LE: x_0 <= 3.537691214515479
# input LE: x_0 <= 3.5476912145154786
# input LE: x_0 <= 3.5576912145154784
# input LE: x_0 <= 3.567691214515478
# input LE: x_0 <= 3.577691214515478
# input LE: x_0 <= 3.587691214515478
# input LE: x_0 <= 3.5976912145154776
# input LE: x_0 <= 3.6076912145154774
# input LE: x_0 <= 3.617691214515477
# input LE: x_0 <= 3.627691214515477
# input LE: x_0 <= 3.6376912145154767
# input LE: x_0 <= 3.6476912145154765
# input LE: x_0 <= 3.6576912145154763
# input LE: x_0 <= 3.667691214515476
# input LE: x_0 <= 3.677691214515476
# input LE: x_0 <= 3.6876912145154757
# input LE: x_0 <= 3.6976912145154754
# input LE: x_0 <= 3.7076912145154752
# input LE: x_0 <= 3.717691214515475
# input LE: x_0 <= 3.727691214515475
# input LE: x_0 <= 3.7376912145154746
# input LE: x_0 <= 3.7476912145154744
# input LE: x_0 <= 3.757691214515474
# input LE: x_0 <= 3.767691214515474
# input LE: x_0 <= 3.7776912145154737
# input LE: x_0 <= 3.7876912145154735
# input LE: x_0 <= 3.7976912145154733
# input LE: x_0 <= 3.807691214515473
# input LE: x_0 <= 3.817691214515473
# input LE: x_0 <= 3.8276912145154727
# input LE: x_0 <= 3.8376912145154725
# input LE: x_0 <= 3.8476912145154722
# input LE: x_0 <= 3.857691214515472
# input LE: x_0 <= 3.867691214515472
# input LE: x_0 <= 3.8776912145154716
# input LE: x_0 <= 3.8876912145154714
# input LE: x_0 <= 3.897691214515471
# input LE: x_0 <= 3.907691214515471
# input LE: x_0 <= 3.9176912145154708
# input LE: x_0 <= 3.9276912145154705
# input LE: x_0 <= 3.9376912145154703
# input LE: x_0 <= 3.94769121451547
# input LE: x_0 <= 3.95769121451547
# input LE: x_0 <= 3.9676912145154697
# input LE: x_0 <= 3.9776912145154695
# input LE: x_0 <= 3.9876912145154693
# input LE: x_0 <= 3.997691214515469
# input LE: x_0 <= 4.007691214515469
# input LE: x_0 <= 4.017691214515469
# input LE: x_0 <= 4.027691214515468
# input LE: x_0 <= 4.037691214515468
# input LE: x_0 <= 4.047691214515468
# input LE: x_0 <= 4.057691214515468
# input LE: x_0 <= 4.067691214515468
# input LE: x_0 <= 4.077691214515467
# input LE: x_0 <= 4.087691214515467
# input LE: x_0 <= 4.097691214515467
# input LE: x_0 <= 4.107691214515467
# input LE: x_0 <= 4.1176912145154665
# input LE: x_0 <= 4.127691214515466
# input LE: x_0 <= 4.137691214515466
# input LE: x_0 <= 4.147691214515466
# input LE: x_0 <= 4.157691214515466
# input LE: x_0 <= 4.167691214515465
# input LE: x_0 <= 4.177691214515465
# input LE: x_0 <= 4.187691214515465
# input LE: x_0 <= 4.197691214515465
# input LE: x_0 <= 4.207691214515465
# input LE: x_0 <= 4.217691214515464
# input LE: x_0 <= 4.227691214515464
# input LE: x_0 <= 4.237691214515464
# input LE: x_0 <= 4.247691214515464
# input LE: x_0 <= 4.2576912145154635
# input LE: x_0 <= 4.267691214515463
# input LE: x_0 <= 4.277691214515463
# input LE: x_0 <= 4.287691214515463
# input LE: x_0 <= 4.297691214515463
# input LE: x_0 <= 4.307691214515462
# input LE: x_0 <= 4.317691214515462
# input LE: x_0 <= 4.327691214515462
# input LE: x_0 <= 4.337691214515462
# input LE: x_0 <= 4.347691214515462
# input LE: x_0 <= 4.357691214515461
# input LE: x_0 <= 4.367691214515461
# input LE: x_0 <= 4.377691214515461
# input LE: x_0 <= 4.387691214515461
# input LE: x_0 <= 4.3976912145154605
# input LE: x_0 <= 4.40769121451546
# input LE: x_0 <= 4.41769121451546
# input LE: x_0 <= 4.42769121451546
# input LE: x_0 <= 4.43769121451546
# input LE: x_0 <= 4.4476912145154595
# input LE: x_0 <= 4.457691214515459
# input LE: x_0 <= 4.467691214515459
# input LE: x_0 <= 4.477691214515459
# input LE: x_0 <= 4.487691214515459
# input LE: x_0 <= 4.497691214515458
# input LE: x_0 <= 4.507691214515458
# input LE: x_0 <= 4.517691214515458
# input LE: x_0 <= 4.527691214515458
# input LE: x_0 <= 4.5376912145154575
# input LE: x_0 <= 4.547691214515457
# input LE: x_0 <= 4.557691214515457
# input LE: x_0 <= 4.567691214515457
# input LE: x_0 <= 4.577691214515457
# input LE: x_0 <= 4.5876912145154565
# input LE: x_0 <= 4.597691214515456
# input LE: x_0 <= 4.607691214515456
# input LE: x_0 <= 4.617691214515456
# input LE: x_0 <= 4.627691214515456
# input LE: x_0 <= 4.637691214515455
# input LE: x_0 <= 4.647691214515455
# input LE: x_0 <= 4.657691214515455
# input LE: x_0 <= 4.667691214515455
# input LE: x_0 <= 4.6776912145154546
# input LE: x_0 <= 4.687691214515454
# input LE: x_0 <= 4.697691214515454
# input LE: x_0 <= 4.707691214515454
# input LE: x_0 <= 4.717691214515454
# input LE: x_0 <= 4.7276912145154535
# input LE: x_0 <= 4.737691214515453
# input LE: x_0 <= 4.747691214515453
# input LE: x_0 <= 4.757691214515453
# input LE: x_0 <= 4.767691214515453
# input LE: x_0 <= 4.777691214515452
# input LE: x_0 <= 4.787691214515452
# input LE: x_0 <= 4.797691214515452
# input LE: x_0 <= 4.807691214515452
# input LE: x_0 <= 4.817691214515452
# input LE: x_0 <= 4.827691214515451
# input LE: x_0 <= 4.837691214515451
# input LE: x_0 <= 4.847691214515451
# input LE: x_0 <= 4.857691214515451
# input LE: x_0 <= 4.8676912145154505
# input LE: x_0 <= 4.87769121451545
# input LE: x_0 <= 4.88769121451545
# input LE: x_0 <= 4.89769121451545
# input LE: x_0 <= 4.90769121451545
# input LE: x_0 <= 4.917691214515449
# input LE: x_0 <= 4.927691214515449
# input LE: x_0 <= 4.937691214515449
# input LE: x_0 <= 4.947691214515449
# input LE: x_0 <= 4.957691214515449
# input LE: x_0 <= 4.967691214515448
# input LE: x_0 <= 4.977691214515448
# input LE: x_0 <= 4.987691214515448
# input LE: x_0 <= 4.997691214515448
# input LE: x_0 <= 5.0076912145154475
# input LE: x_0 <= 5.017691214515447
# input LE: x_0 <= 5.027691214515447
# input LE: x_0 <= 5.037691214515447
# input LE: x_0 <= 5.047691214515447
# input LE: x_0 <= 5.0576912145154465
# input LE: x_0 <= 5.067691214515446
# input LE: x_0 <= 5.077691214515446
# input LE: x_0 <= 5.087691214515446
# input LE: x_0 <= 5.097691214515446
# input LE: x_0 <= 5.107691214515445
# input LE: x_0 <= 5.117691214515445
# input LE: x_0 <= 5.127691214515445
# input GE: x_0 >= 2.967691214515491
# input GE: x_3 >= -1.408120229258977
# input GE: x_5 >= -0.790702170757714
# input GE: x_6 >= 4.24127975754059
# input GE: x_7 >= -0.3615292659832898
# input GE: x_8 >= -0.6037614142464092
# input GE: x_3 >= -1.418120229258977
# input GE: x_6 >= 4.23127975754059
# input GE: x_3 >= -1.428120229258977
# input GE: x_6 >= 4.22127975754059
# input GE: x_3 >= -1.438120229258977
# input GE: x_6 >= 4.2112797575405905
# input GE: x_3 >= -1.448120229258977
# input GE: x_3 >= -1.458120229258977
#
# Final constraints:
# [docplex.mp.LinearConstraint[input GE](x_0,GE,2.967691214515491), docplex.mp.LinearConstraint[input GE](x_3,GE,-1.458120229258977), docplex.mp.LinearConstraint[input GE](x_5,GE,-0.790702170757714), docplex.mp.LinearConstraint[input GE](x_6,GE,4.2112797575405905), docplex.mp.LinearConstraint[input GE](x_7,GE,-0.3615292659832898), docplex.mp.LinearConstraint[input GE](x_8,GE,-0.6037614142464092)]
# [docplex.mp.LinearConstraint[input LE](x_0,LE,5.127691214515445), docplex.mp.LinearConstraint[input LE](x_3,LE,-1.0781202292589767), docplex.mp.LinearConstraint[input LE](x_5,LE,-0.4507021707577137), docplex.mp.LinearConstraint[input LE](x_6,LE,4.571279757540583), docplex.mp.LinearConstraint[input LE](x_7,LE,-0.031529265983289645), docplex.mp.LinearConstraint[input LE](x_8,LE,-0.2837614142464089)]

# %% [markdown]
# **TODO:** Rewrite pair of expression of type $x \le c$ and $x \ge c$ to $x = c$:

# %%
linear_constraints = testing_model.find_matching_linear_constraints('input')
linear_constraints
# Out:
# [docplex.mp.LinearConstraint[input LE](x_0,LE,5.127691214515445),
#  docplex.mp.LinearConstraint[input GE](x_0,GE,2.967691214515491),
#  docplex.mp.LinearConstraint[input LE](x_3,LE,-1.0781202292589767),
#  docplex.mp.LinearConstraint[input GE](x_3,GE,-1.458120229258977),
#  docplex.mp.LinearConstraint[input LE](x_5,LE,-0.4507021707577137),
#  docplex.mp.LinearConstraint[input GE](x_5,GE,-0.790702170757714),
#  docplex.mp.LinearConstraint[input LE](x_6,LE,4.571279757540583),
#  docplex.mp.LinearConstraint[input GE](x_6,GE,4.2112797575405905),
#  docplex.mp.LinearConstraint[input LE](x_7,LE,-0.031529265983289645),
#  docplex.mp.LinearConstraint[input GE](x_7,GE,-0.3615292659832898),
#  docplex.mp.LinearConstraint[input LE](x_8,LE,-0.2837614142464089),
#  docplex.mp.LinearConstraint[input GE](x_8,GE,-0.6037614142464092)]

# %% [markdown]
# Note that `x_6` is actually equal to `4.24127975754059`

# %%
number_of_inputs = len(dataframe.columns.drop('target'))
for i in range(number_of_inputs):
	constraints_of_x_i = filter(lambda x: x.lhs.name == f'x_{i}', linear_constraints)
	constraints = [c for c in constraints_of_x_i]

	if len(constraints) == 2:
		if constraints[0].rhs.constant == constraints[1].rhs.constant:
			testing_model.remove_constraints(constraints)
			testing_model.add_constraint(constraints[0].lhs == constraints[0].rhs, 'input')

# %%
improved_explanation = testing_model.find_matching_linear_constraints('input')
improved_explanation
# Out:
# [docplex.mp.LinearConstraint[input LE](x_0,LE,5.127691214515445),
#  docplex.mp.LinearConstraint[input GE](x_0,GE,2.967691214515491),
#  docplex.mp.LinearConstraint[input LE](x_3,LE,-1.0781202292589767),
#  docplex.mp.LinearConstraint[input GE](x_3,GE,-1.458120229258977),
#  docplex.mp.LinearConstraint[input LE](x_5,LE,-0.4507021707577137),
#  docplex.mp.LinearConstraint[input GE](x_5,GE,-0.790702170757714),
#  docplex.mp.LinearConstraint[input LE](x_6,LE,4.571279757540583),
#  docplex.mp.LinearConstraint[input GE](x_6,GE,4.2112797575405905),
#  docplex.mp.LinearConstraint[input LE](x_7,LE,-0.031529265983289645),
#  docplex.mp.LinearConstraint[input GE](x_7,GE,-0.3615292659832898),
#  docplex.mp.LinearConstraint[input LE](x_8,LE,-0.2837614142464089),
#  docplex.mp.LinearConstraint[input GE](x_8,GE,-0.6037614142464092)]

# %% [markdown]
# ### Pretty Printing the Explanation

# %%
def get_variable_index(variable: docplex.mp.dvar.Var) -> int:
	index = variable.name.split('_')[1]
	return int(index)

# %%
def print_explanation(explanation: list[docplex.mp.constr.LinearConstraint]):
	for e in explanation:
		variable = e.lhs
		index = get_variable_index(variable)
		feature_name = dataframe.columns[index]
		print(feature_name, e.sense.operator_symbol, e.rhs)

# %%
print_explanation(improved_explanation)
# Out:
# RI <= 5.127691214515445
# RI >= 2.967691214515491
# Al <= -1.0781202292589767
# Al >= -1.458120229258977
# K <= -0.4507021707577137
# K >= -0.790702170757714
# Ca <= 4.571279757540583
# Ca >= 4.2112797575405905
# Ba <= -0.031529265983289645
# Ba >= -0.3615292659832898
# Fe <= -0.2837614142464089
# Fe >= -0.6037614142464092

# %% [markdown]
# ## Comparing with Anchor

# %%
from anchor import utils

# %% [markdown]
# ### Loading the Dataset

# %%
d = utils.load_csv_dataset(
	data=f'datasets/{dataset_name}/test.csv',
	target_idx=-1,
	feature_names=['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','target'],
	# categorical_features=None,
	# features_to_use=None,
	# feature_transformations=None,
	# discretize=False,
	# balance=False,
	# fill_na='-1',
	# filter_fn=None,
	skip_first=True
)

# %% [markdown]
# ### Explainer

# %%
from anchor import anchor_tabular

# %%
explainer = anchor_tabular.AnchorTabularExplainer(
    d.class_names,
    d.feature_names,
    d.train,
    d.categorical_names)

# %%
predict_fn = lambda x: tf.argmax(keras_model.predict(x)[0]).numpy().reshape(1)

# %%
for a in d.train:
	a == data[i]
# Out:
# /tmp/ipykernel_23061/1890216175.py:2: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   a == data[i]

# %%
exp = explainer.explain_instance(data[i, :-1], predict_fn)
# Out:
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 989us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 944us/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 965us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 919us/step
# 4/4 [==============================] - 0s 999us/step
# 4/4 [==============================] - 0s 921us/step
# 4/4 [==============================] - 0s 982us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 931us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 980us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 916us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 922us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 868us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 976us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 957us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1000us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 964us/step
# 4/4 [==============================] - 0s 912us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 974us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 928us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1000us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 925us/step
# 4/4 [==============================] - 0s 984us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 958us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 915us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 994us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 985us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 969us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 947us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 952us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 936us/step
# 4/4 [==============================] - 0s 997us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 917us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 920us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 997us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 926us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 895us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 923us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 984us/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 937us/step
# 4/4 [==============================] - 0s 965us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 926us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 955us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 954us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 970us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 991us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 941us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 963us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 960us/step
# 4/4 [==============================] - 0s 917us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 927us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 965us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 941us/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 944us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 958us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 913us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 986us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 996us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 968us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 928us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 925us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 927us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 912us/step
# 4/4 [==============================] - 0s 967us/step
# 4/4 [==============================] - 0s 922us/step
# 4/4 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 913us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 922us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 923us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 958us/step
# 4/4 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 977us/step
# 4/4 [==============================] - 0s 882us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 930us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 921us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 945us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 933us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 0s 972us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 942us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 937us/step
# 4/4 [==============================] - 0s 922us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 962us/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 912us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 996us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 916us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 933us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 935us/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 890us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 944us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 913us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 918us/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 914us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 906us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 930us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 959us/step
# 4/4 [==============================] - 0s 906us/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 891us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 956us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 913us/step
# 4/4 [==============================] - 0s 980us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 916us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 972us/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 956us/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 989us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 936us/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 969us/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 7ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 946us/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 68ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 29ms/step

# %%
exp.names()
# Out:
# ['RI > -0.64', 'K > -0.60', 'Na <= 0.84', 'Si > -0.81', 'Al > -0.57']

# %%
print_explanation(improved_explanation)
# Out:
# RI <= 5.127691214515445
# RI >= 2.967691214515491
# Al <= -1.0781202292589767
# Al >= -1.458120229258977
# K <= -0.4507021707577137
# K >= -0.790702170757714
# Ca <= 4.571279757540583
# Ca >= 4.2112797575405905
# Ba <= -0.031529265983289645
# Ba >= -0.3615292659832898
# Fe <= -0.2837614142464089
# Fe >= -0.6037614142464092

# %%
exp.precision()
# Out:
# 0.2526837324525186

# %%
exp.coverage()
# Out:
# 0.3867

# %%
# explainer.explain_instance(
# 	data_row,
# 	classifier_fn,
# 	threshold=0.95,
# 	delta=0.1,
# 	tau=0.15,
# 	batch_size=100,
# 	max_anchor_size=None,
# 	desired_label=None,
# 	**kwargs)
